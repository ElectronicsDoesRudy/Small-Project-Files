# %%
pip install deepface

# %%
import cv2
from google.colab.patches import cv2_imshow
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

i = cv2.imread("kamala harris.jpg")
gray = cv2.cvtColor(i,cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 3)
for (x,y,w,h) in faces:
  cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 3)
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x900>

# %%
from deepface import DeepFace
predictions = DeepFace.analyze(i)
print(predictions)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 26-07-21 13:22:55 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to /root/.deepface/weights/facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 255MB/s]
# Action: age:  25%|██▌       | 1/4 [00:03<00:11,  4.00s/it]
# 26-07-21 13:22:57 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to /root/.deepface/weights/age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
# ...

# %%
p = predictions[0]['dominant_emotion']
#print(p)
a=predictions[0]['age']
#print(a)
g=predictions[0]['gender']
#print(g)
cv2.rectangle(i , (x,y) , (x+w,y+h) , (0,255,0) , 3)
cv2.putText(i, p, (x,y), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,255), 2, cv2.LINE_AA)
cv2.putText(i, str(g) , (x+5,y+50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,255), 2, cv2.LINE_AA)
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x900>
