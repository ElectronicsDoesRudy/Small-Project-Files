# %%
import pandas as pd
data = pd.read_csv("https://confrecordings.ams3.digitaloceanspaces.com/Life_Expectancy_Data.csv")
print(data.isnull().sum())
print(data.shape)
print(data.dtypes)
# Out:
# Country                              0
# Year                                 0
# Status                             308
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64
# (2938, 22)
# Country                             object
# ...
